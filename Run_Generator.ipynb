# %% [markdown]
# # Puter Token Generator
# Run the cells below to generate tokens.

# %%
# Check environment
# !which chromium-browser || which chromium
# !node --version
# !ls -la node_modules/puppeteer-real-browser 2>/dev/null || echo 'Installing...'
![ -d node_modules/puppeteer-real-browser ] || npm install puppeteer-real-browser

# %%
# Generate SINGLE token
# !bash run_single.sh

# %%
# Generate MULTIPLE tokens (5 by default)
# !bash run_multi.sh 5

# %%
# View all generated tokens
# !cat tokens/all_tokens.txt 2>/dev/null || echo 'No tokens yet'

# %%
# Download tokens file
from IPython.display import FileLink
FileLink('tokens/all_tokens.txt')
